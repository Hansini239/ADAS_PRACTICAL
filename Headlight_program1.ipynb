# %%
import cv2
import numpy as np
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input, decode_predictions

model = MobileNetV2(weights ='imagenet')
image = cv2.imread("night.jpg")

img = cv2.resize(image,(224,224))

x = np.expand_dims(img,axis =0)
x = preprocess_input(x)

predictions = model.predict(x)

print(decode_predictions(predictions,top=3)[0])

gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
brightness = np.mean(gray)
print("Ambinent Brigthness:",brightness)
if brightness < 80:
    print("headlights on")
else:
    print("headlights off")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# [('n09472597', 'volcano', np.float32(0.15070492)), ('n01930112', 'nematode', np.float32(0.06611047)), ('n01630670', 'common_newt', np.float32(0.027521221))]
# Ambinent Brigthness: 29.215933506728486
# headlights on
